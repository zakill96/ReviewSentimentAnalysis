# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

import seaborn as sns
import re
import konlpy
from konlpy.tag import Okt
from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix

# %%
df_kakao = pd.read_excel('kakao.xlsx')
df_toss = pd.read_excel('toss.xlsx')
df_sh = pd.read_excel('sh.xlsx')
df_kb = pd.read_excel('kb.xlsx')

# %%
df_kakao=df_kakao.drop(['Unnamed: 0','name'], axis=1)

# %%
df_kakao
# Out:
#                      date  score  \
# 0     2022-03-21 11:13:07      3
# 1     2022-03-20 09:38:57      1
# 2     2022-03-19 15:08:02      4
# 3     2022-03-19 13:23:10      1
# 4     2022-03-18 18:24:24      1
# ...                   ...    ...
# 17840 2017-07-27 00:23:22      5
# 17841 2017-07-27 00:17:45      5
# 17842 2017-07-27 00:17:30      5
# 17843 2017-07-27 00:15:32      5
# 17844 2017-07-27 00:14:35      5
#
#                                                  content  thumbsUp
# 0                             상담원이 말투들이 좀 딱딱하셔서 좀 불편합니다.         0
# 1      거 개빡치네요 입출금계좌 만들려고 했는데 실명확인하래서 했고 다시했는데 안되고 탈퇴...         0
# 2      앱 자체난 너무 조아요 근데 26일 지금 하는데 저 돈이 넉넉하게 천원 넘게 있는데...         0
# 3                                        설치가안되는데이유를모르겠네요         0
# 4      비밀번호를 두개다 잊어버리는 바람에.. 분명 제가 간수 못 한게 잘못이긴 하죠 그래...         3
# ...                                                  ...       ...
# 17840                                             기대합니다.         0
# 17841                                            기대중입니다b        11
# 17842                                                최고!         1
# 17843                                            기대 기대!!         2
# 17844                                    오 역시 잘 만들었네요!!♡         2
#
# [17845 rows x 4 columns]

# %%
okt = Okt()

# %%
url ="https://raw.githubusercontent.com/yoonkt200/FastCampusDataset/master/korean_stopwords.txt"
stopwords = pd.read_csv(url).values.tolist()

# %%
stopwords
# Out:
# [['휴'],
#  ['아이구'],
#  ['아이쿠'],
#  ['아이고'],
#  ['어'],
#  ['나'],
#  ['우리'],
#  ['저희'],
#  ['따라'],
#  ['의해'],
#  ['을'],
#  ['를'],
#  ['에'],
#  ['의'],
#  ['가'],
#  ['으로'],
#  ['로'],
#  ['에게'],
#  ['뿐이다'],
#  ['의거하여'],
#  ['근거하여'],
#  ['입각하여'],
#  ['기준으로'],
#  ['예하면'],
#  ['예를 들면'],
#  ['예를 들자면'],
#  ['저'],
#  ['소인'],
#  ['소생'],
#  ['저희'],
#  ['지말고'],
#  ['하지마'],
#  ['하지마라'],
#  ['다른'],
#  ['물론'],
#  ['또한'],
#  ['그리고'],
#  ['비길수 없다'],
#  ['해서는 안된다'],
#  ['뿐만 아니라'],
#  ['만이 아니다'],
#  ['만은 아니다'],
#  ['막론하고'],
#  ['관계없이'],
#  ['그치지 않다'],
#  ['그러나'],
#  ['그런데'],
#  ['하지만'],
#  ['든간에'],
#  ['논하지 않다'],
#  ['따지지 않다'],
#  ['설사'],
#  ['비록'],
#  ['더라도'],
#  ['아니면'],
#  ['만 못하다'],
#  ['하는 편이 낫다'],
#  ['불문하고'],
#  ['향하여'],
#  ['향해서'],
#  ['향하다'],
#  ['쪽으로'],
#  ['틈타'],
#  ['이용하여'],
#  ['타다'],
#  ['오르다'],
#  ['제외하고'],
#  ['이 외에'],
#  ['이 밖에'],
#  ['하여야'],
#  ['비로소'],
#  ['한다면 몰라도'],
#  ['외에도'],
#  ['이곳'],
#  ['여기'],
#  ['부터'],
#  ['기점으로'],
#  ['따라서'],
#  ['할 생각이다'],
#  ['하려고하다'],
#  ['이리하여'],
#  ['그리하여'],
#  ['그렇게 함으로써'],
#  ['하지만'],
#  ['일때'],
#  ['할때'],
#  ['앞에서'],
#  ['중에서'],
#  ['보는데서'],
#  ['으로써'],
#  ['로써'],
#  ['까지'],
#  ['해야한다'],
#  ['일것이다'],
#  ['반드시'],
#  ['할줄알다'],
#  ['할수있다'],
#  ['할수있어'],
#  ['임에 틀림없다'],
#  ['한다면'],
#  ['등'],
#  ['등등'],
#  ['제'],
#  ['겨우'],
#  ['단지'],
#  ['다만'],
#  ['할뿐'],
#  ['딩동'],
#  ['댕그'],
#  ['대해서'],
#  ['대하여'],
#  ['대하면'],
#  ['훨씬'],
#  ['얼마나'],
#  ['얼마만큼'],
#  ['얼마큼'],
#  ['남짓'],
#  ['여'],
#  ['얼마간'],
#  ['약간'],
#  ['다소'],
#  ['좀'],
#  ['조금'],
#  ['다수'],
#  ['몇'],
#  ['얼마'],
#  ['지만'],
#  ['하물며'],
#  ['또한'],
#  ['그러나'],
#  ['그렇지만'],
#  ['하지만'],
#  ['이외에도'],
#  ['대해 말하자면'],
#  ['뿐이다'],
#  ['다음에'],
#  ['반대로'],
#  ['반대로 말하자면'],
#  ['이와 반대로'],
#  ['바꾸어서 말하면'],
#  ['바꾸어서 한다면'],
#  ['만약'],
#  ['그렇지않으면'],
#  ['까악'],
#  ['툭'],
#  ['딱'],
#  ['삐걱거리다'],
#  ['보드득'],
#  ['비걱거리다'],
#  ['꽈당'],
#  ['응당'],
#  ['해야한다'],
#  ['에 가서'],
#  ['각'],
#  ['각각'],
#  ['여러분'],
#  ['각종'],
#  ['각자'],
#  ['제각기'],
#  ['하도록하다'],
#  ['와'],
#  ['과'],
#  ['그러므로'],
#  ['그래서'],
#  ['고로'],
#  ['한 까닭에'],
#  ['하기 때문에'],
#  ['거니와'],
#  ['이지만'],
#  ['대하여'],
#  ['관하여'],
#  ['관한'],
#  ['과연'],
#  ['실로'],
#  ['아니나다를가'],
#  ['생각한대로'],
#  ['진짜로'],
#  ['한적이있다'],
#  ['하곤하였다'],
#  ['하'],
#  ['하하'],
#  ['허허'],
#  ['아하'],
#  ['거바'],
#  ['와'],
#  ['오'],
#  ['왜'],
#  ['어째서'],
#  ['무엇때문에'],
#  ['어찌'],
#  ['하겠는가'],
#  ['무슨'],
#  ['어디'],
#  ['어느곳'],
#  ['더군다나'],
#  ['하물며'],
#  ['더욱이는'],
#  ['어느때'],
#  ['언제'],
#  ['야'],
#  ['이봐'],
#  ['어이'],
#  ['여보시오'],
#  ['흐흐'],
#  ['흥'],
#  ['휴'],
#  ['헉헉'],
#  ['헐떡헐떡'],
#  ['영차'],
#  ['여차'],
#  ['어기여차'],
#  ['끙끙'],
#  ['아야'],
#  ['앗'],
#  ['아야'],
#  ['콸콸'],
#  ['졸졸'],
#  ['좍좍'],
#  ['뚝뚝'],
#  ['주룩주룩'],
#  ['솨'],
#  ['우르르'],
#  ['그래도'],
#  ['또'],
#  ['그리고'],
#  ['바꾸어말하면'],
#  ['바꾸어말하자면'],
#  ['혹은'],
#  ['혹시'],
#  ['답다'],
#  ['및'],
#  ['그에 따르는'],
#  ['때가 되어'],
#  ['즉'],
#  ['지든지'],
#  ['설령'],
#  ['가령'],
#  ['하더라도'],
#  ['할지라도'],
#  ['일지라도'],
#  ['지든지'],
#  ['몇'],
#  ['거의'],
#  ['하마터면'],
#  ['인젠'],
#  ['이젠'],
#  ['된바에야'],
#  ['된이상'],
#  ['만큼\t어찌됏든'],
#  ['그위에'],
#  ['게다가'],
#  ['점에서 보아'],
#  ['비추어 보아'],
#  ['고려하면'],
#  ['하게될것이다'],
#  ['일것이다'],
#  ['비교적'],
#  ['좀'],
#  ['보다더'],
#  ['비하면'],
#  ['시키다'],
#  ['하게하다'],
#  ['할만하다'],
#  ['의해서'],
#  ['연이서'],
#  ['이어서'],
#  ['잇따라'],
#  ['뒤따라'],
#  ['뒤이어'],
#  ['결국'],
#  ['의지하여'],
#  ['기대여'],
#  ['통하여'],
#  ['자마자'],
#  ['더욱더'],
#  ['불구하고'],
#  ['얼마든지'],
#  ['마음대로'],
#  ['주저하지 않고'],
#  ['곧'],
#  ['즉시'],
#  ['바로'],
#  ['당장'],
#  ['하자마자'],
#  ['밖에 안된다'],
#  ['하면된다'],
#  ['그래'],
#  ['그렇지'],
#  ['요컨대'],
#  ['다시 말하자면'],
#  ['바꿔 말하면'],
#  ['즉'],
#  ['구체적으로'],
#  ['말하자면'],
#  ['시작하여'],
#  ['시초에'],
#  ['이상'],
#  ['허'],
#  ['헉'],
#  ['허걱'],
#  ['바와같이'],
#  ['해도좋다'],
#  ['해도된다'],
#  ['게다가'],
#  ['더구나'],
#  ['하물며'],
#  ['와르르'],
#  ['팍'],
#  ['퍽'],
#  ['펄렁'],
#  ['동안'],
#  ['이래'],
#  ['하고있었다'],
#  ['이었다'],
#  ['에서'],
#  ['로부터'],
#  ['까지'],
#  ['예하면'],
#  ['했어요'],
#  ['해요'],
#  ['함께'],
#  ['같이'],
#  ['더불어'],
#  ['마저'],
#  ['마저도'],
#  ['양자'],
#  ['모두'],
#  ['습니다'],
#  ['가까스로'],
#  ['하려고하다'],
#  ['즈음하여'],
#  ['다른'],
#  ['다른 방면으로'],
#  ['해봐요'],
#  ['습니까'],
#  ['했어요'],
#  ['말할것도 없고'],
#  ['무릎쓰고'],
#  ['개의치않고'],
#  ['하는것만 못하다'],
#  ['하는것이 낫다'],
#  ['매'],
#  ['매번'],
#  ['들'],
#  ['모'],
#  ['어느것'],
#  ['어느'],
#  ['로써'],
#  ['갖고말하자면'],
#  ['어디'],
#  ['어느쪽'],
#  ['어느것'],
#  ['어느해'],
#  ['어느 년도'],
#  ['라 해도'],
#  ['언젠가'],
#  ['어떤것'],
#  ['어느것'],
#  ['저기'],
#  ['저쪽'],
#  ['저것'],
#  ['그때'],
#  ['그럼'],
#  ['그러면'],
#  ['요만한걸'],
#  ['그래'],
#  ['그때'],
#  ['저것만큼'],
#  ['그저'],
#  ['이르기까지'],
#  ['할 줄 안다'],
#  ['할 힘이 있다'],
#  ['너'],
#  ['너희'],
#  ['당신'],
#  ['어찌'],
#  ['설마'],
#  ['차라리'],
#  ['할지언정'],
#  ['할지라도'],
#  ['할망정'],
#  ['할지언정'],
#  ['구토하다'],
#  ['게우다'],
#  ['토하다'],
#  ['메쓰겁다'],
#  ['옆사람'],
#  ['퉤'],
#  ['쳇'],
#  ['의거하여'],
#  ['근거하여'],
#  ['의해'],
#  ['따라'],
#  ['힘입어'],
#  ['그'],
#  ['다음'],
#  ['버금'],
#  ['두번째로'],
#  ['기타'],
#  ['첫번째로'],
#  ['나머지는'],
#  ['그중에서'],
#  ['견지에서'],
#  ['형식으로 쓰여'],
#  ['입장에서'],
#  ['위해서'],
#  ['단지'],
#  ['의해되다'],
#  ['하도록시키다'],
#  ['뿐만아니라'],
#  ['반대로'],
#  ['전후'],
#  ['전자'],
#  ['앞의것'],
#  ['잠시'],
#  ['잠깐'],
#  ['하면서'],
#  ['그렇지만'],
#  ['다음에'],
#  ['그러한즉'],
#  ['그런즉'],
#  ['남들'],
#  ['아무거나'],
#  ['어찌하든지'],
#  ['같다'],
#  ['비슷하다'],
#  ['예컨대'],
#  ['이럴정도로'],
#  ['어떻게'],
#  ['만약'],
#  ['만일'],
#  ['위에서 서술한바와같이'],
#  ['인 듯하다'],
#  ['하지 않는다면'],
#  ['만약에'],
#  ['무엇'],
#  ['무슨'],
#  ['어느'],
#  ['어떤'],
#  ['아래윗'],
#  ['조차'],
#  ['한데'],
#  ['그럼에도 불구하고'],
#  ['여전히'],
#  ['심지어'],
#  ['까지도'],
#  ['조차도'],
#  ['하지 않도록'],
#  ['않기 위하여'],
#  ['때'],
#  ['시각'],
#  ['무렵'],
#  ['시간'],
#  ['동안'],
#  ['어때'],
#  ['어떠한'],
#  ['하여금'],
#  ['네'],
#  ['예'],
#  ['우선'],
#  ['누구'],
#  ['누가 알겠는가'],
#  ['아무도'],
#  ['줄은모른다'],
#  ['줄은 몰랏다'],
#  ['하는 김에'],
#  ['겸사겸사'],
#  ['하는바'],
#  ['그런 까닭에'],
#  ['한 이유는'],
#  ['그러니'],
#  ['그러니까'],
#  ['때문에'],
#  ['그'],
#  ['너희'],
#  ['그들'],
#  ['너희들'],
#  ['타인'],
#  ['것'],
#  ['것들'],
#  ['너'],
#  ['위하여'],
#  ['공동으로'],
#  ['동시에'],
#  ['하기 위하여'],
#  ['어찌하여'],
#  ['무엇때문에'],
#  ['붕붕'],
#  ['윙윙'],
#  ['나'],
#  ['우리'],
#  ['엉엉'],
#  ['휘익'],
#  ['윙윙'],
#  ['오호'],
#  ['아하'],
#  ['어쨋든'],
#  ['만 못하다\t하기보다는'],
#  ['차라리'],
#  ['하는 편이 낫다'],
#  ['흐흐'],
#  ['놀라다'],
#  ['상대적으로 말하자면'],
#  ['마치'],
#  ['아니라면'],
#  ['쉿'],
#  ['그렇지 않으면'],
#  ['그렇지 않다면'],
#  ['안 그러면'],
#  ['아니었다면'],
#  ['하든지'],
#  ['아니면'],
#  ['이라면'],
#  ['좋아'],
#  ['알았어'],
#  ['하는것도'],
#  ['그만이다'],
#  ['어쩔수 없다'],
#  ['하나'],
#  ['일'],
#  ['일반적으로'],
#  ['일단'],
#  ['한켠으로는'],
#  ['오자마자'],
#  ['이렇게되면'],
#  ['이와같다면'],
#  ['전부'],
#  ['한마디'],
#  ['한항목'],
#  ['근거로'],
#  ['하기에'],
#  ['아울러'],
#  ['하지 않도록'],
#  ['않기 위해서'],
#  ['이르기까지'],
#  ['이 되다'],
#  ['로 인하여'],
#  ['까닭으로'],
#  ['이유만으로'],
#  ['이로 인하여'],
#  ['그래서'],
#  ['이 때문에'],
#  ['그러므로'],
#  ['그런 까닭에'],
#  ['알 수 있다'],
#  ['결론을 낼 수 있다'],
#  ['으로 인하여'],
#  ['있다'],
#  ['어떤것'],
#  ['관계가 있다'],
#  ['관련이 있다'],
#  ['연관되다'],
#  ['어떤것들'],
#  ['에 대해'],
#  ['이리하여'],
#  ['그리하여'],
#  ['여부'],
#  ['하기보다는'],
#  ['하느니'],
#  ['하면 할수록'],
#  ['운운'],
#  ['이러이러하다'],
#  ['하구나'],
#  ['하도다'],
#  ['다시말하면'],
#  ['다음으로'],
#  ['에 있다'],
#  ['에 달려 있다'],
#  ['우리'],
#  ['우리들'],
#  ['오히려'],
#  ['하기는한데'],
#  ['어떻게'],
#  ['어떻해'],
#  ['어찌됏어'],
#  ['어때'],
#  ['어째서'],
#  ['본대로'],
#  ['자'],
#  ['이'],
#  ['이쪽'],
#  ['여기'],
#  ['이것'],
#  ['이번'],
#  ['이렇게말하자면'],
#  ['이런'],
#  ['이러한'],
#  ['이와 같은'],
#  ['요만큼'],
#  ['요만한 것'],
#  ['얼마 안 되는 것'],
#  ['이만큼'],
#  ['이 정도의'],
#  ['이렇게 많은 것'],
#  ['이와 같다'],
#  ['이때'],
#  ['이렇구나'],
#  ['것과 같이'],
#  ['끼익'],
#  ['삐걱'],
#  ['따위'],
#  ['와 같은 사람들'],
#  ['부류의 사람들'],
#  ['왜냐하면'],
#  ['중의하나'],
#  ['오직'],
#  ['오로지'],
#  ['에 한하다'],
#  ['하기만 하면'],
#  ['도착하다'],
#  ['까지 미치다'],
#  ['도달하다'],
#  ['정도에 이르다'],
#  ['할 지경이다'],
#  ['결과에 이르다'],
#  ['관해서는'],
#  ['여러분'],
#  ['하고 있다'],
#  ['한 후'],
#  ['혼자'],
#  ['자기'],
#  ['자기집'],
#  ['자신'],
#  ['우에 종합한것과같이'],
#  ['총적으로 보면'],
#  ['총적으로 말하면'],
#  ['총적으로'],
#  ['대로 하다'],
#  ['으로서'],
#  ['참'],
#  ['그만이다'],
#  ['할 따름이다'],
#  ['쿵'],
#  ['탕탕'],
#  ['쾅쾅'],
#  ['둥둥'],
#  ['봐'],
#  ['봐라'],
#  ['아이야'],
#  ['아니'],
#  ['와아'],
#  ['응'],
#  ['아이'],
#  ['참나'],
#  ['년'],
#  ['월'],
#  ['일'],
#  ['령'],
#  ['영'],
#  ['일'],
#  ['이'],
#  ['삼'],
#  ['사'],
#  ['오'],
#  ['육'],
#  ['륙'],
#  ['칠'],
#  ['팔'],
#  ['구'],
#  ['이천육'],
#  ['이천칠'],
#  ['이천팔'],
#  ['이천구'],
#  ['하나'],
#  ['둘'],
#  ['셋'],
#  ['넷'],
#  ['다섯'],
#  ['여섯'],
#  ['일곱'],
#  ['여덟'],
#  ['아홉'],
#  ['령'],
#  ['영'],
#  '아예',
#  '하나',
#  '짜증',
#  '쓰레기',
#  '만하',
#  '지금',
#  '가요',
#  '어제',
#  '자꾸',
#  '언제',
#  '조앙',
#  '점점',
#  '나름',
#  '여기',
#  '항상',
#  '최악',
#  '진짜',
#  '여름날',
#  '체적',
#  '더욱',
#  '가장',
#  '항상',
#  '최고',
#  '아주',
#  '정말',
#  '사용',
#  '완전',
#  '최고다',
#  '매우',
#  '미니',
#  '계속',
#  '쵝오',
#  '짱짱',
#  '해도',
#  '산책',
#  '갑자기',
#  '오델',
#  '미리내',
#  '다시',
#  '이후',
#  '아예',
#  '하나',
#  '짜증',
#  '쓰레기',
#  '만하',
#  '지금',
#  '가요',
#  '어제',
#  '자꾸',
#  '언제',
#  '조앙',
#  '점점',
#  '나름',
#  '여기',
#  '항상',
#  '최악',
#  '진짜',
#  '여름날',
#  '체적',
#  '더욱',
#  '가장',
#  '항상',
#  '최고',
#  '아주',
#  '정말',
#  '사용',
#  '완전',
#  '최고다',
#  '매우',
#  '미니',
#  '계속',
#  '쵝오',
#  '짱짱',
#  '해도',
#  '산책',
#  '갑자기',
#  '오델',
#  '미리내',
#  '다시',
#  '이후']

# %%
stopwords_alpha = ['아예', '하나', '짜증', '쓰레기', '만하', '지금', '가요', '어제', '자꾸', '언제', '조앙', '점점', '나름', '여기', '항상', '최악', '진짜', '여름날', '체적', '더욱', '가장', '항상', '최고', '아주', '정말', '사용', '완전', '최고다', '매우', '미니', '계속', '쵝오', '짱짱', '해도', '산책', '갑자기', '오델', '미리내', '다시', '이후']
for word in stopwords_alpha:
    stopwords.append(word)

# %%
def apply_regular_expression(content):
    hangul = re.compile('[^ ㄱ-ㅣ 가-힣]')
    result = hangul.sub('', str(content)) 
    return result

# %%
corpus = "".join(map(str,(df_kakao['content'].tolist())))
nouns = okt.nouns(apply_regular_expression(corpus))
counter = Counter(nouns)
counter.most_common(10)
# Out:
# [('계좌', 1447),
#  ('사용', 1437),
#  ('은행', 1344),
#  ('카카오', 1333),
#  ('뱅크', 1177),
#  ('앱', 1172),
#  ('인증', 935),
#  ('왜', 853),
#  ('계속', 756),
#  ('오류', 736)]

# %%
def content_cleaning(content):
    hangul = re.compile('[^ ㄱ-ㅣ 가-힣]')
    result = hangul.sub('', content)
    okt = Okt()  # 형태소 추출
    nouns = okt.nouns(result)
    nouns = [x for x in nouns if len(x) > 1]
    nouns = [x for x in nouns if x not in stopwords]
    return nouns

vect = CountVectorizer(tokenizer = lambda x: content_cleaning(x))
bow_vect = vect.fit_transform(map(str,(df_kakao['content'].tolist())))
word_list = vect.get_feature_names()
count_list = bow_vect.toarray().sum(axis=0)

# %%
corpus = "".join(map(str,(df_kakao['content'].tolist())))
nouns = okt.nouns(apply_regular_expression(corpus))

# %%
counter = Counter(nouns)

# %%
counter.most_common(10)
# Out:
# [('계좌', 1447),
#  ('사용', 1437),
#  ('은행', 1344),
#  ('카카오', 1333),
#  ('뱅크', 1177),
#  ('앱', 1172),
#  ('인증', 935),
#  ('왜', 853),
#  ('계속', 756),
#  ('오류', 736)]

# %%
word_count_dict = dict(zip(word_list, count_list))

# %%
tfidf_vectorizer = TfidfTransformer()
tf_idf_vect = tfidf_vectorizer.fit_transform(bow_vect)

# %%
print(tf_idf_vect.shape)
# Out:
# (17845, 5885)

# %%
vect.vocabulary_
# Out:
# {'상담': 2516,
#  '말투': 1656,
#  '입출금': 4110,
#  '계좌': 345,
#  '실명': 2978,
#  '확인': 5777,
#  '하래': 5537,
#  '탈퇴': 5209,
#  '해지': 5640,
#  '어쩌': 3296,
#  '자체': 4174,
#  '천원': 4881,
#  '설치': 2636,
#  '이유': 3952,
#  '비밀번호': 2377,
#  '바람': 1969,
#  '분명': 2309,
#  '간수': 61,
#  '비번': 2379,
#  '이상': 3927,
#  '다음': 1057,
#  '도움': 1255,
#  '대책': 1184,
#  '다운': 1055,
#  '어캐': 3316,
#  '미성년': 1932,
#  '외국인': 3616,
#  '차별': 4817,
#  '한국인': 5571,
#  '카트': 5095,
#  '발급': 2021,
#  '외국': 3614,
#  '오류': 3535,
#  '때문': 1401,
#  '초기': 4924,
#  '대안': 1168,
#  '영상통화': 3498,
#  '방법': 2052,
#  '이제': 3964,
#  '이용': 3945,
#  '은행': 3833,
#  '거래': 209,
#  '가능': 7,
#  '카카오': 5089,
#  '뱅크': 2105,
#  '명의': 1759,
#  '등록': 1369,
#  '건가': 238,
#  '기능': 708,
#  '추가': 4980,
#  '코로나바이러스': 5140,
#  '백신': 2092,
#  '접종': 4359,
#  '핸드폰': 5648,
#  '인증': 4021,
#  '반복': 2008,
#  '그때': 607,
#  '매번': 1674,
#  '기도': 711,
#  '안내': 3128,
#  '마찬가지': 1596,
#  '현상': 5698,
#  '기술': 731,
#  '조속': 4476,
#  '해결': 5619,
#  '변경': 2162,
#  '납득': 887,
#  '모바일': 1783,
#  '신분증': 2946,
#  '젠데': 4450,
#  '실물': 2979,
#  '카드': 5065,
#  '로만': 1504,
#  '본인': 2248,
#  '어디': 3267,
#  '구성': 522,
#  '도감': 1232,
#  '이용자': 3949,
#  '진행': 4758,
#  '고고': 354,
#  '송금': 2742,
#  '처리': 4864,
#  '라면': 1439,
#  '당장': 1128,
#  '워드': 3722,
#  '카뱅': 5071,
#  '보유': 2214,
#  '한도': 5578,
#  '만원': 1636,
#  '이체': 3981,
#  '한지': 5595,
#  '개월': 162,
#  '문의': 1882,
#  '대리인': 1151,
#  '김유경': 774,
#  '가족': 40,
#  '거나': 205,
#  '지인': 4708,
#  '그냥': 596,
#  '인간': 3996,
#  '거주': 230,
#  '지역': 4700,
#  '심지어': 3010,
#  '똑디': 1411,
#  '경우': 315,
#  '택배': 5222,
#  '거기': 204,
#  '배송': 2078,
#  '정보': 4375,
#  '그거': 590,
#  '고해': 401,
#  '삭제': 2492,
#  '다른': 1037,
#  '통장': 5261,
#  '여러분': 3423,
#  '절대': 4330,
#  '갸삭기들': 201,
#  '안철수': 3176,
#  '단일': 1089,
#  '화가': 5751,
#  '가가': 0,
#  '벌써': 2140,
#  '만세': 1631,
#  '이레': 3900,
#  '접속': 4355,
#  '이안': 3937,
#  '게속': 276,
#  '하라': 5533,
#  '안해': 3183,
#  '이건': 3880,
#  '어추구': 3312,
#  '어플': 3328,
#  '재발': 4235,
#  '잠기': 4204,
#  '안나': 3127,
#  '스마트': 2820,
#  '출금': 4999,
#  '코드': 5137,
#  '인식': 4013,
#  '개발자': 143,
#  '화면': 5757,
#  '햇빛': 5656,
#  '도대체': 1235,
#  '몇번': 1771,
#  '실행': 2999,
#  '무슨': 1848,
#  '뭔가': 1911,
#  '설정': 2635,
#  '나니': 815,
#  '이번': 3919,
#  '조금': 4460,
#  '어이': 3290,
#  '참고': 4833,
#  '갤럭시': 194,
#  '노트': 966,
#  '별롭니': 2176,
#  '발생': 2027,
#  '알림': 3191,
#  '간편': 68,
#  '명쾌': 1764,
#  '편리': 5386,
#  '제발': 4425,
#  '개설': 152,
#  '사기꾼': 2429,
#  '악용': 3121,
#  '평점': 5410,
#  '주기도': 4555,
#  '가까이': 4,
#  '썻는데': 3035,
#  '정도': 4370,
#  '전쟁': 4315,
#  '선포': 2626,
#  '당신': 1126,
#  '먼저': 1699,
#  '누가': 981,
#  '이기': 3887,
#  '결제': 302,
#  '연체': 3481,
#  '월급': 3745,
#  '날인': 863,
#  '사람': 2435,
#  '위험': 3776,
#  '기변': 723,
#  '촬영': 4953,
#  '요구': 3634,
#  '뱅킹': 2107,
#  '증귄사': 4646,
#  '합치': 5614,
#  '중복': 4616,
#  '야마': 3240,
#  '공인': 432,
#  '인증서': 4022,
#  '시절': 2914,
#  '향수': 5671,
#  '지경': 4667,
#  '더군다나': 1206,
#  '구형': 540,
#  '역시': 3456,
#  '네이버': 930,
#  '삼성': 2510,
#  '인뱅': 4006,
#  '보편성': 2232,
#  '존심': 4500,
#  '절차': 4337,
#  '보안': 2210,
#  '구멍': 515,
#  '신저': 2962,
#  '고집': 392,
#  '부리면': 2272,
#  '계정': 343,
#  '기기': 705,
#  '지원': 4704,
#  '그룹': 618,
#  '전체': 4319,
#  '세인': 2683,
#  '학생': 5563,
#  '체크카드': 4918,
#  '시작': 2912,
#  '입력': 4101,
#  '튕김': 5292,
#  '금일': 678,
#  '업무': 3372,
#  '차질': 4822,
#  '대처': 1185,
#  '수정': 2783,
#  '일단': 4037,
#  '은행원': 3837,
#  '문제': 1886,
#  '연락': 3468,
#  '집합소': 4773,
#  '금감원': 654,
#  '민원': 1951,
#  '넣기': 926,
#  '수수료': 2770,
#  '악플': 3124,
#  '고객': 352,
#  '센터': 2688,
#  '전화': 4323,
#  '한번': 5582,
#  '피부': 5502,
#  '시중': 2917,
#  '대출': 1189,
#  '절반': 4334,
#  '이해': 3990,
#  '서류': 2584,
#  '담당': 1109,
#  '정작': 4395,
#  '답변': 1117,
#  '앵무새': 3236,
#  '수준': 2784,
#  '해외': 5633,
#  '예금': 3511,
#  '적금': 4277,
#  '하나로': 5521,
#  '금액': 668,
#  '한글': 5572,
#  '표시': 5447,
#  '리지': 1547,
#  '튕깁니': 5293,
#  '보고': 2190,
#  '주식': 4575,
#  '투자': 5279,
#  '이벤트': 3922,
#  '참여': 4836,
#  '통합': 5265,
#  '증거': 4643,
#  '금도': 658,
#  '신청': 2966,
#  '박스': 1994,
#  '크기': 5161,
#  '츌시': 5035,
#  '신규': 2934,
#  '아파트': 3114,
#  '불가': 2322,
#  '출중': 5010,
#  '그것': 591,
#  '속편': 2723,
#  '처음': 4869,
#  '카메라': 5068,
#  '사진': 2480,
#  '로그인': 1497,
#  '니스': 1020,
#  '국제': 549,
#  '사기': 2428,
#  '문자': 1883,
#  '스트레스': 2850,
#  '업데이트': 3358,
#  '기만': 717,
#  '시간': 2883,
#  '가끔': 5,
#  '구글플레이': 502,
#  '수단': 2751,
#  '평가': 5403,
#  '요즘': 3651,
#  '오륜': 3538,
#  '제출': 4444,
#  '기각': 698,
#  '괜찬음': 483,
#  '혁신': 5695,
#  '토스': 5244,
#  '제일': 4438,
#  '오늘': 3529,
#  '신나요': 2938,
#  '실용': 2989,
#  '효과': 5827,
#  '스팀': 2853,
#  '누적': 988,
#  '애초': 3219,
#  '리뷰': 1537,
#  '상태': 2537,
#  '하루': 5538,
#  '이틀': 3984,
#  '보기': 2194,
#  '수십': 2774,
#  '기존': 750,
#  '로딩': 1501,
#  '숨은그림찾기': 2810,
#  '사용자': 2462,
#  '환경': 5782,
#  '직관': 4729,
#  '속도': 2720,
#  '사나': 2430,
#  '중간': 4606,
#  '인터넷': 4025,
#  '기계': 700,
#  '열기': 3485,
#  '튕기': 5289,
#  '세이프': 2682,
#  '저금': 4258,
#  '생기': 2562,
#  '티머니': 5321,
#  '충전': 5020,
#  '는걸': 1008,
#  '버그': 2110,
#  '홍보': 5746,
#  '일수': 4062,
#  '속지': 2722,
#  '작동': 4180,
#  '작성': 4182,
#  '조화': 4493,
#  '불량': 2331,
#  '입장': 4107,
#  '무척': 1867,
#  '안정': 3167,
#  '개발': 142,
#  '좌파': 4542,
#  '기업': 736,
#  '마이너스': 1589,
#  '직장인': 4735,
#  '신용': 2955,
#  '가안': 29,
#  '간다': 56,
#  '태생': 5218,
#  '급전': 693,
#  '피료해': 5501,
#  '케이': 5134,
#  '연봉': 3473,
#  '자산': 4155,
#  '마통': 1601,
#  '이억천': 3940,
#  '원도': 3732,
#  '하란': 5535,
#  '부로': 2269,
#  '해킹': 5642,
#  '중국': 4608,
#  '왤케': 3613,
#  '분동': 2305,
#  '식용': 2927,
#  '숫자': 2811,
#  '정지': 4399,
#  '거지': 231,
#  '년전': 942,
#  '때메': 1400,
#  '본사': 2246,
#  '제주도': 4443,
#  '성남': 2644,
#  '서울': 2597,
#  '별하나': 2185,
#  '건의': 251,
#  '사항': 2486,
#  '모임': 1790,
#  '계해': 347,
#  '잔액': 4194,
#  '얼마': 3346,
#  '금융': 672,
#  '대상': 1162,
#  '면서': 1742,
#  '청해': 4906,
#  '어케': 3317,
#  '일주일': 4079,
#  '여권': 3418,
#  '방사': 2054,
#  '해제': 5635,
#  '미만': 1928,
#  '생각': 2560,
#  '뭐합': 1909,
#  '먹튀': 1698,
#  '시일': 2911,
#  '다른사람': 1038,
#  '피해': 5508,
#  '살이': 2505,
#  '여간': 3416,
#  '찾기': 4847,
#  '번호': 2139,
#  '청소년증': 4900,
#  '통화': 5268,
#  '적오': 4281,
#  '서비스': 2591,
#  '기억': 735,
#  '제대로': 4417,
#  '최대한': 4962,
#  '려고': 1488,
#  '강제': 118,
#  '종료': 4515,
#  '입금': 4099,
#  '롭니': 1516,
#  '나이': 834,
#  '사랑': 2438,
#  '개미': 141,
#  '동안': 1301,
#  '비교': 2368,
#  '전달': 4291,
#  '일일': 4071,
#  '계산': 335,
#  '사본': 2446,
#  '갤러리': 193,
#  '저장': 4266,
#  '막장': 1605,
#  '무한': 1869,
#  '패턴': 5355,
#  '내일': 906,
#  '청소년': 4899,
#  '민증': 1954,
#  '공유': 431,
#  '조치': 4489,
#  '이력': 3901,
#  '일괄': 4035,
#  '필요': 5512,
#  '디자인': 1384,
#  '저축': 4271,
#  '튕겨': 5284,
#  '갤폴드쓰리': 198,
#  '프로필': 5480,
#  '이미지': 3913,
#  '공동': 420,
#  '시대': 2895,
#  '신용카드': 2958,
#  '네트워크': 932,
#  '다가': 1027,
#  '자동': 4137,
#  '하나요': 5522,
#  '시도': 2896,
#  '먹통': 1697,
#  '기간': 699,
#  '압류': 3204,
#  '포인트': 5423,
#  '선물': 2609,
#  '가입': 37,
#  '중단': 4610,
#  '바보': 1979,
#  '현실': 5699,
#  '만약': 1633,
#  '위치': 3773,
#  '추적': 4986,
#  '비상': 2380,
#  '소득': 2695,
#  '신용등급': 2956,
#  '보증': 2224,
#  '보험': 2233,
#  '증권': 4644,
#  '발행': 2038,
#  '거절': 228,
#  '자유': 4164,
#  '감지': 98,
#  '재부팅': 4236,
#  '바로': 1972,
#  '전액': 4307,
#  '세미': 2669,
#  '기분': 725,
#  '집사': 4769,
#  '용량': 3664,
#  '줄알': 4603,
#  '불편': 2348,
#  '필수': 5511,
#  '못함': 1820,
#  '신뢰': 2941,
#  '믿음': 1956,
#  '위해': 3775,
#  '시스템': 2905,
#  '매일': 1677,
#  '매달': 1671,
#  '겨우': 291,
#  '타자': 5195,
#  '근처': 643,
#  '걷기': 252,
#  '운동': 3702,
#  '종일': 4521,
#  '미자': 1941,
#  '만들기': 1622,
#  '성인': 2653,
#  '도일': 1256,
#  '편의': 5391,
#  '성은': 2651,
#  '정기예금': 4368,
#  '혜택': 5722,
#  '창렬': 4840,
#  '주자': 4585,
#  '뚝배기': 1422,
#  '그늘': 597,
#  '지게': 4666,
#  '날짜': 865,
#  '직접': 4737,
#  '보통': 2229,
#  '오픈': 3563,
#  '순서': 2798,
#  '편집': 5396,
#  '만족': 1641,
#  '세로': 2667,
#  '은근': 3823,
#  '노인': 961,
#  '쓰기': 3047,
#  '혹시': 5737,
#  '이름': 3904,
#  '정체': 4401,
#  '오해': 3567,
#  '보편': 2231,
#  '푸시': 5452,
#  '진인': 4746,
#  '교통카드': 495,
#  '분리': 2307,
#  '완벽': 3591,
#  '금투': 684,
#  '청약': 4902,
#  '금지': 683,
#  '출시': 5005,
#  '유무': 3789,
#  '고등학교': 358,
#  '사생': 2449,
#  '대회': 1203,
#  '작품': 4189,
#  '만듬': 1624,
#  '굿굿굿': 559,
#  '하락': 5534,
#  '캐릭터': 5103,
#  '주시': 4574,
#  '지윘다': 4707,
#  '지방': 4690,
#  '지점': 4712,
#  '조회': 4494,
#  '불가능': 2324,
#  '대기': 1140,
#  '별로': 2175,
#  '여러': 3421,
#  '샤오미': 2578,
#  '롬업': 1515,
#  '튕기네': 5290,
#  '현준': 5702,
#  '여친': 3444,
#  '김사랑': 771,
#  '친구': 5052,
#  '외로': 3618,
#  '연결': 3461,
#  '메모': 1718,
#  '증발': 4652,
#  '색깔': 2556,
#  '영구': 3494,
#  '된거': 1319,
#  '되돌리기': 1317,
#  '심플': 3011,
#  '면허증': 1746,
#  '리해': 1554,
#  '두운': 1334,
#  '바닥': 1967,
#  '반사': 2009,
#  '홀로그램': 5741,
#  '전부': 4299,
#  '유의': 3799,
#  '다만': 1040,
#  '야외': 3242,
#  '비밀': 2376,
#  '상실': 2527,
#  '자주': 4173,
#  '위로': 3764,
#  '안보': 3156,
#  '보이': 2215,
#  '면도': 1738,
#  '페이': 5376,
#  '사탕': 2484,
#  '발림': 2024,
#  '만수무강': 1632,
#  '인성': 4010,
#  '별개': 2171,
#  '개도': 134,
#  '부분': 2277,
#  '하든': 5532,
#  '만이': 1637,
#  '참나': 4834,
#  '은애': 3827,
#  '겨냥': 290,
#  '새해': 2555,
#  '문구': 1874,
#  '자금': 4128,
#  '조성': 4475,
#  '쵝오네': 4979,
#  '메이트': 1727,
#  '죠르디': 4547,
#  '왜왜': 3608,
#  '반영': 2014,
#  '노답': 950,
#  '실패': 2998,
#  '횟수': 5824,
#  '제한': 4447,
#  '캐쉬': 5104,
#  '옛날': 3524,
#  '쿠팡': 5153,
#  '주문': 4565,
#  '단계': 1076,
#  '자라': 4141,
#  '자꾸만': 4133,
#  '해당': 5623,
#  '시오': 2908,
#  '커뮤니티': 5115,
#  '소통': 2716,
#  '공간': 409,
#  '프로': 5470,
#  '다방면': 1042,
#  '트럭': 5302,
#  '안드로이드': 3149,
#  '관리': 461,
#  '장점': 4228,
#  '전번': 4298,
#  '산업': 2499,
#  '스파이': 2854,
#  '메뉴': 1713,
#  '무료': 1840,
#  '따름': 1391,
#  '쫄보': 4798,
#  '식이': 2928,
#  '전혀': 4322,
#  '이자': 3957,
#  '캐시': 5106,
#  '맘에듬': 1660,
#  '강추': 120,
#  '예의': 3520,
#  '내용': 905,
#  '간단': 57,
#  '매력': 1673,
#  '초과': 4923,
#  '정리': 4373,
#  '선구자': 2604,
#  '활용': 5795,
#  '읍니': 3858,
#  '굿굿': 558,
#  '거의': 225,
#  '해주시': 5637,
#  '자기': 4130,
#  '풀기': 5455,
#  '잔고': 4190,
#  '가게': 1,
#  '반도': 2005,
#  '서민': 2588,
#  '없었슴': 3380,
#  '앱입니닸': 3234,
#  '내야': 904,
#  '최첨단': 4976,
#  '씈다': 3055,
#  '쉬움': 2813,
#  '조음': 4481,
#  '불신': 2340,
#  '막상': 1604,
#  '개편': 183,
#  '마스터': 1579,
#  '모드': 1777,
#  '다크': 1070,
#  '크리스마스': 5163,
#  '어보': 3283,
#  '충성': 5019,
#  '컴맹': 5124,
#  '최소': 4965,
#  '터치': 5227,
#  '등등': 1368,
#  '업뎃': 3359,
#  '무거워': 1827,
#  '연등': 3467,
#  '장난': 4214,
#  '덕분': 1216,
#  '최강': 4956,
#  '적립': 4279,
#  '절약': 4336,
#  '맘속': 1659,
#  '설명': 2631,
#  '상세': 2524,
#  '주민': 4566,
#  '등록증': 1371,
#  '보시': 2208,
#  '프로그램': 5473,
#  '주로': 4561,
#  '로그아웃': 1495,
#  '강사': 114,
#  '소리': 2698,
#  '현재': 5700,
#  '존재': 4501,
#  '납부': 888,
#  '마감': 1560,
#  '전날': 4290,
#  '뱅이': 2104,
#  '단어': 1085,
#  '참으로': 4837,
#  '아유': 3094,
#  '레쉬': 1478,
#  '방금': 2047,
#  '자유적금': 4167,
#  '새벽': 2553,
#  '불구': 2328,
#  '잘만': 4197,
#  '가뜩이나': 13,
#  '개선': 151,
#  '환불': 5784,
#  '박규': 1989,
#  '오웅': 3551,
#  '대체': 1186,
#  '선택': 2625,
#  '카톡': 5092,
#  '며칠': 1736,
#  '부터': 2296,
#  '우수': 3689,
#  '월햇': 3756,
#  '다한': 1071,
#  '후기': 5829,
#  '실망': 2977,
#  '최대': 4961,
#  '미래': 1925,
#  '죠아욤': 4549,
#  '보관': 2191,
#  '보지': 2226,
#  '얼른': 3344,
#  '데카': 1230,
#  '살수': 2504,
#  '펀리': 5364,
#  '느낌': 1005,
#  '부탁': 2295,
#  '니엘': 1022,
#  '회사': 5809,
#  '예전': 3521,
#  '방식': 2057,
#  '가지': 42,
#  '만드': 1618,
#  '일회용': 4088,
#  '나오니': 830,
#  '수로': 2762,
#  '역대': 3449,
#  '부담': 2261,
#  '접근성': 4353,
#  '모두': 1775,
#  '부디': 2265,
#  '롱런': 1517,
#  '버드': 2111,
#  '배경': 2067,
#  '표기': 5444,
#  '자크': 4175,
#  '결재': 299,
#  '졸라': 4505,
#  '버러지': 2112,
#  '클라스': 5166,
#  '테크': 5235,
#  '업체': 3375,
#  '알약': 3196,
#  '발견': 2019,
#  '그간': 589,
#  '갱신': 199,
#  '업데': 3357,
#  '이크': 3982,
#  '마음대로': 1585,
#  '중이': 4624,
#  '분통': 2319,
#  '뭣데로임': 1914,
#  '그릔가': 620,
#  '제거': 4411,
#  '공지': 437,
#  '취소': 5024,
#  '몇개': 1769,
#  '에러': 3398,
#  '앱업뎃': 3232,
#  '래서': 1459,
#  '모니터링': 1773,
#  '현금': 5696,
#  '관리자': 463,
#  '해답': 5622,
#  '나중': 838,
#  '별도': 2174,
#  '부연': 2284,
#  '고생': 371,
#  '볼일': 2254,
#  '편의점': 5392,
#  '점검': 4339,
#  '리마': 1534,
#  '팝업': 5346,
#  '낭패': 892,
#  '디오': 1382,
#  '오오': 3547,
#  '아애': 3089,
#  '애애악': 3215,
#  '자단': 4135,
#  '텔레뱅킹': 5239,
#  '골탕': 406,
#  '일쑤': 4064,
#  '외국어': 3615,
#  '듣기': 1358,
#  '조합': 4492,
#  '폐기': 5412,
#  '얼굴인식': 3341,
#  '마스크': 1578,
#  '때매': 1399,
#  '지문': 4688,
#  '자매': 4149,
#  '용돈': 3663,
#  '최근': 4960,
#  '와이파이': 3586,
#  '정보통신망': 4378,
#  '어쩌란건': 3302,
#  '부부': 2276,
#  '비용': 2381,
#  '디다': 1376,
#  '안녕하십니까': 3132,
#  '취소돠엇다': 5025,
#  '한다해': 5576,
#  '적지': 4285,
#  '버튼': 2123,
#  '액수': 3222,
#  '모든': 1778,
#  '지난달': 4673,
#  '아래': 3071,
#  '지향': 4727,
#  '발전': 2033,
#  '굳이': 556,
#  '모험': 1793,
#  '차단': 4810,
#  '매도': 1672,
#  '일요일': 4066,
#  '곳도': 407,
#  '관련': 460,
#  '사무': 2444,
#  '편리햐': 5387,
#  '영통': 3505,
#  '하필': 5556,
#  '휴대폰': 5857,
#  '나위': 832,
#  '당첨': 1129,
#  '도착': 1264,
#  '년월': 941,
#  '먼지': 1700,
#  '포함': 5432,
#  '예수금': 3517,
#  '기회': 762,
#  '또한': 1410,
#  '키카': 5173,
#  '엉망': 3388,
#  '진창': 4755,
#  '개월차': 163,
#  '주전': 4587,
#  '전용': 4309,
#  '일차': 4081,
#  '퍼센트': 5362,
#  '스탬프': 2841,
#  '줌뭐': 4605,
#  '잘못': 4198,
#  '요약': 3645,
#  '부모님': 2274,
#  '퇴사': 5273,
#  '제시': 4431,
#  '전환': 4327,
#  '현황': 5708,
#  '실시간': 2986,
#  '상품': 2542,
#  '상생': 2523,
#  '소비': 2704,
#  '원금': 3730,
#  '유일': 3802,
#  '제외': 4434,
#  '국민': 543,
#  '신한': 2969,
#  '무늬': 1832,
#  '소액': 2710,
#  '회외': 5817,
#  '수익금': 2780,
#  '달마': 1105,
#  '한마음': 5580,
#  '유저': 3804,
#  '어플리케이션': 3329,
#  '신경': 2930,
#  '박수': 1993,
#  '허니': 5680,
#  '되풀이': 1318,
#  '페지': 5381,
#  '로또': 1502,
#  '명당': 1749,
#  '대박': 1157,
#  '볼라': 2253,
#  '화이팅': 5765,
#  '최신': 4967,
#  '버전': 2120,
#  '업뎃하': 3364,
#  '개꼴': 129,
#  '버젼': 2121,
#  '초장': 4943,
#  '학생증': 5564,
#  '일반': 4049,
#  '제로': 4421,
#  '안드': 3145,
#  '아이': 3095,
#  '보호자': 2237,
#  '동의': 1303,
#  '장애인': 4227,
#  '정렬': 4372,
#  '주말': 4563,
#  '허락': 5682,
#  '의문': 3868,
#  '듭니': 1360,
#  '그게': 592,
#  '다임': 1064,
#  '무조건': 1861,
#  '갈수록': 80,
#  '별명': 2180,
#  '일정': 4077,
#  '택시': 5223,
#  '타고': 5181,
#  '회도': 5805,
#  '훼손': 5852,
#  '수가': 2747,
#  '한국': 5569,
#  '검토': 265,
#  '뭐임': 1906,
#  '얼마나': 3347,
#  '주기': 4554,
#  '달라': 1099,
#  '일자': 4073,
#  '어케합': 3323,
#  '감동': 87,
#  '업계': 3353,
#  '위인': 3768,
#  '걱정': 237,
#  '목돈': 1794,
#  '작자': 4185,
#  '개수': 153,
#  '종합': 4524,
#  '낮처': 893,
#  '초동': 4928,
#  '트루': 5305,
#  '조만간': 4467,
#  '가짐': 44,
#  '검색': 257,
#  '물질': 1898,
#  '빨간색': 2405,
#  '얼룩': 3343,
#  '대한': 1198,
#  '한눈': 5575,
#  '파악': 5334,
#  '전화번호': 4325,
#  '눌리질': 1002,
#  '만드거': 1619,
#  '안고': 3126,
#  '성질': 2656,
#  '신분': 2945,
#  '벨벳': 2160,
#  '사진촬영': 2482,
#  '초점': 4944,
#  '프렌즈': 5469,
#  '통신망': 5256,
#  '정상': 4381,
#  '유용': 3797,
#  '축하': 4994,
#  '슬슬': 2866,
#  '구글': 501,
#  '코리아': 5141,
#  '부족': 2291,
#  '공과금': 416,
#  '지출': 4718,
#  '차이': 4821,
#  '간접': 64,
#  '제테크': 4445,
#  '개인': 164,
#  '주머니': 4564,
#  '즐거움': 4640,
#  '행복': 5664,
#  '더니': 1208,
#  '업떼이트': 3370,
#  '담날': 1108,
#  '리셋': 1539,
#  '찡찡러이': 4807,
#  '추천': 4989,
#  '불만': 2332,
#  '아치': 3112,
#  '진동': 4740,
#  '욕처': 3659,
#  '집단': 4768,
#  '경비': 311,
#  '게임': 280,
#  '데이': 1225,
#  '진행중': 4759,
#  '가면': 20,
#  ...}

# %%
invert_index_vectorizer = {v: k for k, v in vect.vocabulary_.items()}
print(str(invert_index_vectorizer)[:100]+'...')
# Out:
# {2516: '상담', 1656: '말투', 4110: '입출금', 345: '계좌', 2978: '실명', 5777: '확인', 5537: '하래', 5209: '탈퇴', 564...

# %% [markdown]
# df_kakao['score'].hist()

# %%
def score_to_label(score):
    if score > 3:
        return 1
    else:
        return 0
    
df_kakao['y'] = df_kakao['score'].apply(lambda x: score_to_label(x))

# %%
x = tf_idf_vect
y = df_kakao['y']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state=1)

# %% [markdown]
# train_test_split(x, y, test_size = 0.3, random_state=1)

# %%
lr = LogisticRegression(random_state = 0)
lr.fit(x_train, y_train)

y_pred = lr.predict(x_test)

# %% [markdown]
# confu = confusion_matrix(y_true = y_test, y_pred = y_pred)
#
# plt.figure(figsize=(4, 3))
# sns.heatmap(confu, annot=True, annot_kws={'size':15}, cmap='OrRd', fmt='.10g')
# plt.title('Confusion Matrix')
# plt.show()

# %%
positive_random_idx = df_kakao[df_kakao['y']==1].sample(275, random_state=12).index.tolist()
negative_random_idx = df_kakao[df_kakao['y']==0].sample(275, random_state=12).index.tolist()

# %%
random_idx = positive_random_idx + negative_random_idx
x = tf_idf_vect[random_idx]
y = df_kakao['y'][random_idx]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=1)

# %%
lr2 = LogisticRegression(random_state = 0)
lr2.fit(x_train, y_train)
y_pred = lr2.predict(x_test)

# %% [markdown]
# confu = confusion_matrix(y_true = y_test, y_pred = y_pred)
#
# plt.figure(figsize=(4, 3))
# sns.heatmap(confu, annot=True, annot_kws={'size':15}, cmap='OrRd', fmt='.10g')
# plt.title('Confusion Matrix')
# plt.show()

# %% [markdown]
# plt.figure(figsize=(10, 8))
# plt.bar(range(len(lr2.coef_[0])), lr2.coef_[0])

# %%
coef_pos_index = sorted(((value, index) for index, value in enumerate(lr2.coef_[0])), reverse = True)
coef_neg_index = sorted(((value, index) for index, value in enumerate(lr2.coef_[0])), reverse = False)
invert_index_vectorizer = {v: k for k, v in vect.vocabulary_.items()}

# %%
print('카카오 긍부정')
# Out:
# 카카오 긍부정

# %%
for coef in coef_pos_index[:20]:
    print(invert_index_vectorizer[coef[1]], coef[0])
# Out:
# 수수료 0.8637126303973804
# 이체 0.8510659554765866
# 쓰기 0.671364394025773
# 송금 0.5925317407670644
# 혁신 0.5865279013335841
# 신속 0.5561992864148764
# 만족 0.49763001877470137
# 이용 0.44572844524752153
# 자주 0.4446222896911967
# 기대 0.3783909545664379
# 애용 0.3755230295505345
# 버튼 0.346247160765585
# 공인 0.345009110974688
# 쉬움 0.3358502496948032
# 혁명 0.32865766554300324
# 편리 0.32865766554300324
# 컴맹 0.32865766554300324
# 쪼아 0.32865766554300324
# 안전성 0.32865766554300324
# 박규 0.32865766554300324

# %%
for coef in coef_neg_index[:40]:
    print(invert_index_vectorizer[coef[1]], coef[0])
# Out:
# 신분증 -1.6947195581282843
# 오류 -1.5969007703923488
# 설치 -1.4822793726886154
# 인증 -1.4608434984636118
# 연결 -1.2584694738772533
# 업데이트 -1.0563211093490625
# 접속 -1.0049924432275483
# 실명 -1.0004117553275347
# 실행 -0.9281693510764913
# 인식 -0.9262192103203365
# 촬영 -0.9139091563657475
# 개설 -0.9009583410544441
# 다운로드 -0.9005523266994793
# 계정 -0.8583188013991832
# 사진 -0.8418135527306652
# 번호 -0.8094724745303541
# 삭제 -0.7885231710050848
# 상담 -0.777836146368034
# 명의 -0.7357485677906138
# 시간 -0.710399388626797
# 사람 -0.687217361488315
# 로그인 -0.6844068745831419
# 대기 -0.6524308455840833
# 실망 -0.6524279361635484
# 푸시 -0.6499118019075129
# 전화 -0.646646491746594
# 페미 -0.6392027719410118
# 하라 -0.6354216008102771
# 계좌 -0.6352483939361542
# 이틀 -0.6315163598010505
# 확인 -0.6301221543143438
# 본인 -0.6285356593460909
# 몇번 -0.627498166315086
# 이름 -0.605880494465454
# 제대로 -0.6034551001253348
# 갤럭시 -0.5947185498537387
# 다른 -0.5928030275511208
# 처음 -0.5753025157520928
# 카카오 -0.5517619515485679
# 주민 -0.5403934410518773

# %%
df = df_toss.drop(['Unnamed: 0','name'], axis=1)

corpus = "".join(map(str,(df['content'].tolist())))
nouns = okt.nouns(apply_regular_expression(corpus))
counter = Counter(nouns)

def content_cleaning(content):
    hangul = re.compile('[^ ㄱ-ㅣ 가-힣]')
    result = hangul.sub('', content)
    okt = Okt()
    nouns = okt.nouns(result)
    nouns = [x for x in nouns if len(x) > 1]
    nouns = [x for x in nouns if x not in stopwords]
    return nouns


vect = CountVectorizer(tokenizer = lambda x: content_cleaning(x))
bow_vect = vect.fit_transform(map(str,(df['content'].tolist())))
word_list = vect.get_feature_names()
count_list = bow_vect.toarray().sum(axis=0)

corpus = "".join(map(str,(df['content'].tolist())))
nouns = okt.nouns(apply_regular_expression(corpus))

counter = Counter(nouns)

counter.most_common(10)

word_count_dict = dict(zip(word_list, count_list))

tfidf_vectorizer = TfidfTransformer()
tf_idf_vect = tfidf_vectorizer.fit_transform(bow_vect)

invert_index_vectorizer = {v: k for k, v in vect.vocabulary_.items()}

def score_to_label(score):
    if score > 3:
        return 1
    else:
        return 0
    
df['y'] = df['score'].apply(lambda x: score_to_label(x))

x = tf_idf_vect
y = df['y']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state=1)

lr = LogisticRegression(random_state = 0)
lr.fit(x_train, y_train)

y_pred = lr.predict(x_test)

positive_random_idx = df[df['y']==1].sample(275, random_state=12).index.tolist()
negative_random_idx = df[df['y']==0].sample(275, random_state=12).index.tolist()

random_idx = positive_random_idx + negative_random_idx
x = tf_idf_vect[random_idx]
y = df['y'][random_idx]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=1)

lr2 = LogisticRegression(random_state = 0)
lr2.fit(x_train, y_train)
y_pred = lr2.predict(x_test)

coef_pos_index = sorted(((value, index) for index, value in enumerate(lr2.coef_[0])), reverse = True)
coef_neg_index = sorted(((value, index) for index, value in enumerate(lr2.coef_[0])), reverse = False)
invert_index_vectorizer = {v: k for k, v in vect.vocabulary_.items()}
print('토스 긍정')
for coef in coef_pos_index[:40]:
    print(invert_index_vectorizer[coef[1]], coef[0])
print('토스 부정')
for coef in coef_neg_index[:20]:
    print(invert_index_vectorizer[coef[1]], coef[0])
# Out:
# 토스 긍정
# 무료 0.45327313629170796
# 그때 0.3690885264652837
# 평생 0.33124793330619573
# 가도 0.3084817081069568
# 소식 0.256658480882349
# 초기 0.2553993354939245
# 해외 0.2404172753053722
# 체크 0.22768391593995446
# 한도 0.21760783770957798
# 적립 0.21062396214676243
# 한번 0.1877442119354348
# 결제 0.1759669689534372
# 이자율 0.17179155012623812
# 보통예금 0.17179155012623812
# 차곡차곡 0.16622072464453352
# 보기 0.1573286845509923
# 파악 0.14460268490165157
# 송금 0.1362781495766371
# 수수료 0.1332010886657362
# 사항 0.13021664709556635
# 정보 0.1293641763918066
# 자동 0.11876390856859086
# 자주 0.11729373642748393
# 모든 0.11526090876391486
# 이체 0.06448729530649999
# 하니 0.03433022809925951
# 읍니 0.019110747971339825
# 프라임 0.018111742556591134
# 힌트 0.0
# 히히히 0.0
# 희망 0.0
# 흥국 0.0
# 흡족 0.0
# 흔적 0.0
# 흑역사 0.0
# 흐헷 0.0
# 흐트려놔 0.0
# 흐트러졌네 0.0
# 휴일 0.0
# 휴무 0.0
# 토스 부정
# 업데이트 -0.6669589750267049
# 계좌 -0.6501906144371253
# 카드 -0.5689557689627338
# 입금 -0.4918957712903887
# 토스 -0.48112408014028146
# 업뎃 -0.44338913595458235
# 인증 -0.40622803938509255
# 제대로 -0.37521050504527903
# 금액 -0.34756751876445746
# 연결 -0.3410934249810233
# 확인 -0.3360791272261237
# 해결 -0.33310478661994714
# 잔액 -0.32022551864182336
# 표시 -0.2947263997029966
# 조회 -0.29168391486188444
# 다해 -0.27860520506562136
# 사람 -0.2765172876786206
# 무슨 -0.27625976316281997
# 입출금 -0.27014490546655623
# 오류 -0.25951589051732615

# %%
df = df_sh.drop(['Unnamed: 0','name'], axis=1)

corpus = "".join(map(str,(df['content'].tolist())))
nouns = okt.nouns(apply_regular_expression(corpus))
counter = Counter(nouns)

def content_cleaning(content):
    hangul = re.compile('[^ ㄱ-ㅣ 가-힣]')
    result = hangul.sub('', content)
    okt = Okt()
    nouns = okt.nouns(result)
    nouns = [x for x in nouns if len(x) > 1]
    nouns = [x for x in nouns if x not in stopwords]
    return nouns

vect = CountVectorizer(tokenizer = lambda x: content_cleaning(x))
bow_vect = vect.fit_transform(map(str,(df['content'].tolist())))
word_list = vect.get_feature_names()
count_list = bow_vect.toarray().sum(axis=0)

corpus = "".join(map(str,(df['content'].tolist())))
nouns = okt.nouns(apply_regular_expression(corpus))

counter = Counter(nouns)

counter.most_common(10)

word_count_dict = dict(zip(word_list, count_list))

tfidf_vectorizer = TfidfTransformer()
tf_idf_vect = tfidf_vectorizer.fit_transform(bow_vect)

invert_index_vectorizer = {v: k for k, v in vect.vocabulary_.items()}

def score_to_label(score):
    if score > 3:
        return 1
    else:
        return 0
    
df['y'] = df['score'].apply(lambda x: score_to_label(x))

x = tf_idf_vect
y = df['y']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state=1)

lr = LogisticRegression(random_state = 0)
lr.fit(x_train, y_train)

y_pred = lr.predict(x_test)

positive_random_idx = df[df['y']==1].sample(275, random_state=12).index.tolist()
negative_random_idx = df[df['y']==0].sample(275, random_state=12).index.tolist()

random_idx = positive_random_idx + negative_random_idx
x = tf_idf_vect[random_idx]
y = df['y'][random_idx]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=1)

lr2 = LogisticRegression(random_state = 0)
lr2.fit(x_train, y_train)
y_pred = lr2.predict(x_test)

coef_pos_index = sorted(((value, index) for index, value in enumerate(lr2.coef_[0])), reverse = True)
coef_neg_index = sorted(((value, index) for index, value in enumerate(lr2.coef_[0])), reverse = False)
invert_index_vectorizer = {v: k for k, v in vect.vocabulary_.items()}
print('신한 긍정')
for coef in coef_pos_index[:20]:
    print(invert_index_vectorizer[coef[1]], coef[0])
print('신한 부정')
for coef in coef_neg_index[:40]:
    print(invert_index_vectorizer[coef[1]], coef[0])
# Out:
# 신한 긍정
# 보기 0.8469360963178793
# 신경 0.7393576712876283
# 설명 0.6719804137268597
# 이벤트 0.5987354014463052
# 인터페이스 0.5871287292167471
# 한눈 0.5661315737042051
# 디자인 0.5390181835114884
# 편리 0.5280379627267668
# 감사 0.5280379627267668
# 바이오인증 0.4572672793401566
# 분부 0.4072441101105063
# 신한은행 0.3666530198703128
# 검색 0.35402269036445644
# 신한 0.34611359084616783
# 해외 0.3087686154360763
# 찾기 0.3087686154360763
# 주문 0.3087686154360763
# 안전성 0.3087686154360763
# 실용 0.3087686154360763
# 스시 0.3087686154360763
# 신한 부정
# 어플 -1.9115975513051353
# 인증 -1.683640719741067
# 로그인 -1.6655678605003106
# 오류 -1.526938719867801
# 실행 -1.4756028570428017
# 접속 -1.4253519554301954
# 설치 -1.34773715619192
# 업데이트 -1.2595873640442512
# 가입 -1.1255319927742287
# 로딩 -1.0938007000749257
# 거래 -0.9797631316588992
# 뱅크 -0.9096800795166688
# 먹통 -0.8991401570684416
# 계좌 -0.8896377395323871
# 해결 -0.8614916045857243
# 전화 -0.7999762961820627
# 데이터 -0.7950482169194586
# 카드 -0.7538399250784684
# 인식 -0.7403094619605799
# 시간 -0.7385498400948399
# 문제 -0.7218395126866186
# 비대 -0.7156898724074048
# 확인 -0.7042700696412212
# 문자 -0.6963569767788987
# 등록 -0.6844147074813433
# 화면 -0.6814609799055625
# 처리 -0.6746843027166236
# 중지 -0.6601220503871663
# 개선 -0.6511951680846574
# 때문 -0.6403278671053692
# 중단 -0.6384205693131351
# 기존 -0.5969974549722843
# 오늘 -0.5969551129577194
# 무슨 -0.5518655793063858
# 난리 -0.5465348167707982
# 서버 -0.5356913497955131
# 건가 -0.5251851316660445
# 통신 -0.5104503612531721
# 수정 -0.5092288604156544
# 사람 -0.5087700356047724

# %%
df = df_kb.drop(['Unnamed: 0','name'], axis=1)

corpus = "".join(map(str,(df['content'].tolist())))
nouns = okt.nouns(apply_regular_expression(corpus))
counter = Counter(nouns)

def content_cleaning(content):
    hangul = re.compile('[^ ㄱ-ㅣ 가-힣]')
    result = hangul.sub('', content)
    okt = Okt()
    nouns = okt.nouns(result)
    nouns = [x for x in nouns if len(x) > 1]
    nouns = [x for x in nouns if x not in stopwords]
    return nouns


vect = CountVectorizer(tokenizer = lambda x: content_cleaning(x))
bow_vect = vect.fit_transform(map(str,(df['content'].tolist())))
word_list = vect.get_feature_names()
count_list = bow_vect.toarray().sum(axis=0)

corpus = "".join(map(str,(df['content'].tolist())))
nouns = okt.nouns(apply_regular_expression(corpus))

counter = Counter(nouns)

counter.most_common(10)

word_count_dict = dict(zip(word_list, count_list))

tfidf_vectorizer = TfidfTransformer()
tf_idf_vect = tfidf_vectorizer.fit_transform(bow_vect)

invert_index_vectorizer = {v: k for k, v in vect.vocabulary_.items()}

def score_to_label(score):
    if score > 3:
        return 1
    else:
        return 0
    
df['y'] = df['score'].apply(lambda x: score_to_label(x))

x = tf_idf_vect
y = df['y']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state=1)

lr = LogisticRegression(random_state = 0)
lr.fit(x_train, y_train)

y_pred = lr.predict(x_test)

positive_random_idx = df[df['y']==1].sample(275, random_state=12).index.tolist()
negative_random_idx = df[df['y']==0].sample(275, random_state=12).index.tolist()

random_idx = positive_random_idx + negative_random_idx
x = tf_idf_vect[random_idx]
y = df['y'][random_idx]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=1)

lr2 = LogisticRegression(random_state = 0)
lr2.fit(x_train, y_train)
y_pred = lr2.predict(x_test)

coef_pos_index = sorted(((value, index) for index, value in enumerate(lr2.coef_[0])), reverse = True)
coef_neg_index = sorted(((value, index) for index, value in enumerate(lr2.coef_[0])), reverse = False)
invert_index_vectorizer = {v: k for k, v in vect.vocabulary_.items()}
print('국민 긍정')
for coef in coef_pos_index[:20]:
    print(invert_index_vectorizer[coef[1]], coef[0])
print('국민 부정')
for coef in coef_neg_index[:20]:
    print(invert_index_vectorizer[coef[1]], coef[0])
# Out:
# 국민 긍정
# 이용 2.1114448904114806
# 이벤트 1.1025037181893107
# 보기 0.9829708448212673
# 기능 0.9639872755229557
# 메뉴 0.9536330003029483
# 자주 0.8469785510529807
# 뱅킹 0.8218312251352009
# 구성 0.8158791676392608
# 업무 0.6832167765816001
# 수수료 0.6365854228334838
# 스타 0.6230010756700486
# 주거 0.6175231952438022
# 디자인 0.5395886648869836
# 입출금 0.5325480582873511
# 방식 0.5194211795911907
# 은행 0.5102091841617317
# 필수 0.5021836547385776
# 속도 0.4898147849803922
# 직관 0.4831088394393295
# 약간 0.47151307595080927
# 국민 부정
# 업데이트 -2.1651334877940633
# 실행 -1.180044262093244
# 어플 -1.1144085122550538
# 설치 -0.9877987978270777
# 오류 -0.9437299418851466
# 무슨 -0.8278335444300527
# 네트워크 -0.7450471126048689
# 삭제 -0.7139143889045276
# 로딩 -0.7042033510417625
# 로그인 -0.6947516097380751
# 루팅 -0.6839765477311496
# 등록 -0.678848994056929
# 처음 -0.6674783657721234
# 먹통 -0.6668543033562221
# 비번 -0.6571022988539112
# 버전 -0.6425245812727247
# 개판 -0.6192194789471289
# 사람 -0.6191403964335808
# 화면 -0.6125843564309545
# 업체 -0.607443660569185
# C:\Users\82108\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
